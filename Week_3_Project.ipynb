# %% [markdown]
# <a href="https://colab.research.google.com/github/charlesochanda/Week-3-Python-Project/blob/master/Week_3_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#Import the required libraries using the import function

# %%
file_1=pd.read_csv('MoringaSchool_CB_CDR_20120507.csv')
file_1
#Load the reqired file onto the notebook
# Out:
#       PRODUTC  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0       Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1         sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2         sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3       Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4       Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# 5        data      0  2012-05-06 23:07:26.0  ...     OTHER  /lrUXVGVcN  /lrUXVGVcN
# 6       Voice      0  2012-05-06 23:08:02.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 7       Voice      0  2012-05-06 23:08:03.0  ...     19e2e  09UjmmY1Ds  09UjmmY1Ds
# 8       Voice      0  2012-05-06 23:08:05.0  ...     19e2e  0DeimCpZOc  0DeimCpZOc
# 9         sms      0  2012-05-06 23:08:43.0  ...     19e2e  01MDiY5F89  01MDiY5F89
# ...

# %%
df1=pd.DataFrame(file_1)
df1.tail()
#Create a data frame/ helps preview the dataset
# Out:
#       PRODUTC  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 21587   Voice      0  2012-05-07 07:00:15.0  ...     19e2e  92419cabe3  4906ef4504
# 21588   Voice     20  2012-05-07 07:00:15.0  ...     19e2e  7773627c12  9ef9616350
# 21589   Voice     29  2012-05-07 07:00:15.0  ...     19e2e  ff4d562703  42072d1dc6
# 21590   Voice    195  2012-05-07 07:00:15.0  ...     19e2e  1e55cfc9d0  43e67db037
# 21591   Voice      0  2012-05-07 07:00:15.0  ...       NaN         NaN         NaN
#
# [5 rows x 10 columns]

# %%
df1.columns=['PRODUCT', 'VALUE', 'DATE', 'CELL', 'NUM_INT_A', 'NUM_INT_B', 'COUNTRY_A', 'COUNTRY_B', 'CELL_ID', 'SITE_ID' ]
df1.head()
# Out:
#   PRODUCT  VALUE                   DATE  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1     sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2     sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3   Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
#
# [5 rows x 10 columns]

# %%
file_2=pd.read_csv('MoringaSchool_CB_CDR_20120508.csv')
file_2
#Load the reqired file onto the notebook

# %%
df2=pd.DataFrame(file_2)
df2.tail()
#Create a data frame/ helps preview the dataset
# Out:
#        PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 284333    data      0  2012-05-08 03:36:44.0  ...     OTHER  ffa6759bb2         NaN
# 284334     sms      0  2012-05-08 03:36:45.0  ...     19e2e  cba68d0aba  6d70dae094
# 284335     sms      0  2012-05-08 03:36:45.0  ...     19e2e  60339d459f  e1a3687210
# 284336     sms      0  2012-05-08 03:36:45.0  ...     19e2e  92a4a0642c  700e13a5cf
# 284337     sms      0  2012-05-08 03:36:45.0  ...       NaN         NaN         NaN
#
# [5 rows x 10 columns]

# %%
df2.columns=['PRODUCT', 'VALUE', 'DATE', 'CELL', 'NUM_INT_A', 'NUM_INT_B', 'COUNTRY_A', 'COUNTRY_B', 'CELL_ID', 'SITE_ID' ]
df2.head()
# Out:
#   PRODUCT  VALUE                   DATE  ... COUNTRY_B     CELL_ID     SITE_ID
# 0     sms      0  2012-05-07 23:02:06.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 1   Voice      0  2012-05-07 23:03:44.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 2     sms      0  2012-05-07 23:04:06.0  ...     19e2e  +laSrk7g6q  +laSrk7g6q
# 3   Voice     37  2012-05-07 23:04:48.0  ...     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4     sms     25  2012-05-07 23:04:58.0  ...     19e2e  +bO+qkSonO  +bO+qkSonO
#
# [5 rows x 10 columns]

# %%
file_3=pd.read_csv('MoringaSchool_CB_CDR_20120509.csv')
file_3
#Load the reqired file onto the notebook
# Out:
#        PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B      CELLID     SIET_ID
# 0        Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1          sms      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2        Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3          sms      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4        Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# 5        Voice     10  2012-05-08 23:03:59.0  ...     19e2e  +e+xcimwre  +e+xcimwre
# 6          sms      0  2012-05-08 23:06:06.0  ...     19e2e  +R5ccmtyJf  +R5ccmtyJf
# 7        Voice     10  2012-05-08 23:06:55.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 8          sms     25  2012-05-08 23:07:09.0  ...     19e2e  13O1+JEun3  13O1+JEun3
# 9          sms      0  2012-05-08 23:07:38.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# ...

# %%
df3=pd.DataFrame(file_3)
df3.tail()
#Create a data frame/ helps preview the dataset
# Out:
#        PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B      CELLID     SIET_ID
# 273965    data      0  2012-05-09 05:10:14.0  ...     OTHER  ffa6759bb2         NaN
# 273966    data      0  2012-05-09 05:10:14.0  ...     OTHER  ffa6759bb2         NaN
# 273967     sms      0  2012-05-09 05:10:14.0  ...     19e2e  253f3e83ab  f11e961893
# 273968     sms    100  2012-05-09 05:10:14.0  ...     OTHER  f9639af5ac  70e2654621
# 273969     sms     50  2012-05-09 05:10:14.0  ...     19e2e  ba6c99885a         a82
#
# [5 rows x 10 columns]

# %%
df3.columns=['PRODUCT', 'VALUE', 'DATE', 'CELL', 'NUM_INT_A', 'NUM_INT_B', 'COUNTRY_A', 'COUNTRY_B', 'CELL_ID', 'SITE_ID' ]
df3.head()
# Out:
#   PRODUCT  VALUE                   DATE  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1     sms      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2   Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3     sms      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
#
# [5 rows x 10 columns]

# %%
file_4=pd.read_csv('cells_geo.csv', delimiter=';')
file_4
# Out:
#       Unnamed: 0       VILLES  ...     CELL_ID   SITE_CODE
# 0              0       ADJAME  ...  fbb2e75af3  0bb492ef17
# 1              1       ADJAME  ...  1502501d78  0bb492ef17
# 2              2       ADJAME  ...  0c2e182a0c  0bb492ef17
# 3              3      ASSINIE  ...  69bdfc69fd  8a1e6ce31f
# 4              4      ASSINIE  ...  7a1029d2ab  8a1e6ce31f
# 5              5      ASSINIE  ...  0b4f56438f  8a1e6ce31f
# 6              6     KRIKOREA  ...  041d2504f5  260dbfedc5
# 7              7        ABOBO  ...  a70c1d263b  56306cc7ca
# 8              8        ABOBO  ...  e2d04ea883  56306cc7ca
# 9              9        ABOBO  ...  ee224cd27e  56306cc7ca
# 10            10        ABOBO  ...  107d0d752c  56306cc7ca
# 11            11        ABOBO  ...  3f766cedc0  c1ccd3443b
# 12            12        ABOBO  ...  b0578cdb7f  c1ccd3443b
# 13            13        ABOBO  ...  18a4221316  c1ccd3443b
# 14            14        ABOBO  ...  1b2bccad1f  c1ccd3443b
# ...

# %%
df4=pd.DataFrame(file_4)
df4.tail()
#Create a data frame/ helps preview the dataset
# Out:
#       Unnamed: 0    VILLES      STATUS  ...          AREA     CELL_ID   SITE_CODE
# 3969        3969  ZUENOULA  In Service  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970        3970  ZUENOULA  In Service  ...  CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971        3971  ZUENOULA  In Service  ...  CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972        3972  ZUENOULA  In Service  ...  CENTRE NORTH  d4a6a0b645  61bee9c70c
# 3973        3973  ZUENOULA  In Service  ...  CENTRE NORTH  f9f3e42589  61bee9c70c
#
# [5 rows x 12 columns]

# %%
project=pd.concat([df1, df2, df3], ignore_index=True )
project.tail()
# Out:
#        PRODUCT  VALUE                   DATE  ... COUNTRY_B     CELL_ID     SITE_ID
# 579895    data      0  2012-05-09 05:10:14.0  ...     OTHER  ffa6759bb2         NaN
# 579896    data      0  2012-05-09 05:10:14.0  ...     OTHER  ffa6759bb2         NaN
# 579897     sms      0  2012-05-09 05:10:14.0  ...     19e2e  253f3e83ab  f11e961893
# 579898     sms    100  2012-05-09 05:10:14.0  ...     OTHER  f9639af5ac  70e2654621
# 579899     sms     50  2012-05-09 05:10:14.0  ...     19e2e  ba6c99885a         a82
#
# [5 rows x 10 columns]

# %%
project_1=project.drop(columns=['CELL','COUNTRY_A','COUNTRY_B'])
project_1.head()
# Out:
#   PRODUCT  VALUE  ...     CELL_ID     SITE_ID
# 0   Voice      0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1     sms      0  ...  /+cKZKIp41  /+cKZKIp41
# 2     sms     25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3   Voice     56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     14  ...  051KhYDCpv  051KhYDCpv
#
# [5 rows x 7 columns]

# %%
project_1[['DATE', 'TIME']] = project_1.DATE.str.split(expand=True)
project_1.head()
# Out:
#   PRODUCT  VALUE        DATE  ...     CELL_ID     SITE_ID        TIME
# 0   Voice      0  2012-05-06  ...  /TJNe+Mmtu  /TJNe+Mmtu  23:04:37.0
# 1     sms      0  2012-05-06  ...  /+cKZKIp41  /+cKZKIp41  23:05:25.0
# 2     sms     25  2012-05-06  ...  /u0FSD+ahi  /u0FSD+ahi  23:05:41.0
# 3   Voice     56  2012-05-06  ...  +cNeJzsTp3  +cNeJzsTp3  23:05:42.0
# 4   Voice     14  2012-05-06  ...  051KhYDCpv  051KhYDCpv  23:06:29.0
#
# [5 rows x 8 columns]

# %%
#To check the dates in the data set

project_1['DATE'].unique().tolist()
# Out:
# ['2012-05-06', '2012-05-07', '2012-05-08', '2012-05-09']

# %%
#To check the products in the dataset
project_1['PRODUCT'].unique().tolist()
# Out:
# ['Voice', 'sms', 'data']

# %%
#Find the volume of usage of data, voice , sms per day:
#Which product is more popular
#How much money does it make for the company
project_1.VALUE.groupby(project_1['PRODUCT']).sum()
# Out:
# PRODUCT
# Voice    6350145
# data      388621
# sms       743367
# Name: VALUE, dtype: int64
